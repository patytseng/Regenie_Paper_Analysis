# %%
library(ggplot2)
library(ggpubr)
library(aod)
library(ROCR)
library(survival)
library(survminer)
# Out:
# Attaching package: ‘survival’
#
#
# The following object is masked from ‘package:aod’:
#
#     rats

# %%
options(jupyter.plot_mimetypes = "image/png", dpi = 300)
options(repr.plot.width = 5, repr.plot.height = 5)

# %%
pheno <- read.csv('~/Torkamani_Projects/20210712_Analysis-RegeniePaper/CAD_PRS/PRS_validator/analysis/aric_cad_post_stdzn_prs_pheno.csv')
pheno$ID <- as.character(pheno$SAMPLE_ID)
pheno$N <- length(pheno$ID)
data <- pheno[,c('ID','N','ISP12','AGISP12')]

file <- read.csv('210809-weights.tmp-PRS_2772827-aric_c1-ancestry_1-N_8264-chrALL.csv')
file <- rbind(file,read.csv('210809-weights.tmp-PRS_2772827-aric_c1-ancestry_3-N_3-chrALL.csv'))
file <- rbind(file,read.csv('210809-weights.tmp-PRS_2772827-aric_c1-ancestry_5-N_508-chrALL.csv'))
file <- rbind(file,read.csv('210809-weights.tmp-PRS_2772827-aric_c1-ancestry_mixed-N_4284-chrALL.csv'))
file$ID <- sapply(strsplit(file$X.sampleID,'_'),'[[',2)
file$PRS <- file$sum_PRS / file$SNP_N
file <- file[,c('ID','sum_PRS')]
data <- merge(data,file,by='ID')


data$ISP12 <- as.factor(data$ISP12)

# %%
data$sum_PRS_std <- ( ( data[['sum_PRS']] - mean(data[['sum_PRS']] )) / sd(data[['sum_PRS']]) )

# %%
plot <- ggplot(data, aes_string('sum_PRS_std', color = 'ISP12')) + 
geom_vline(xintercept = 0, linetype = 'longdash') +
geom_vline(xintercept = mean(data[data$ISP12==0,'sum_PRS_std']), linetype = 'longdash', color = '#F8766D') +
geom_vline(xintercept = mean(data[data$ISP12==1,'sum_PRS_std']), linetype = 'longdash', color = '#00BFC4') +
geom_density(color = 'black') + 
geom_density() + 
theme_classic()

# %%
plot
ggsave('PRS_Plot.png', 
       device = 'png', 
       width = 5, 
       height = 5, 
       units = "in", 
       path = '~/Torkamani_Projects/20210712_Analysis-RegeniePaper/CAD_PRS/SCT/PRS_Calculated/')

# %%
logit <- glm(formula(paste0("ISP12 ~", 'sum_PRS_std')), data = data, family = binomial)
summary <- summary(logit)
coeff <- summary$coefficients[2,1]
error <- summary$coefficients[2,2]

# %%
logit_results <- data.frame('sum_PRS_std',exp(as.numeric(coeff)), exp(as.numeric(coeff)) * as.numeric(error))
names(logit_results) <- c('PRS_Score','Log_Odds','Error')

# %%
plot <- ggplot(logit_results, aes(x = PRS_Score, y = Log_Odds)) + 
geom_point() + 
geom_errorbar(aes(ymin=Log_Odds-(1.96*Error), ymax=Log_Odds+(1.96*Error)), width=.5) +
theme_classic()

# %%
plot
ggsave('Log_Odds_Plot.png', 
       device = 'png', 
       width = 5, 
       height = 5, 
       units = "in", 
       path = '~/Torkamani_Projects/20210712_Analysis-RegeniePaper/CAD_PRS/SCT/PRS_Calculated/')

# %%
logit_results[logit_results$Log_Odds == max(logit_results$Log_Odds),]
# Out:
#   PRS_Score   Log_Odds Error
# 1 sum_PRS_std 1.13268  0.02548531

# %%
pred <- prediction(data[['sum_PRS_std']],data$ISP12)
perf <- performance(pred,"sens","spec")

perf_data <- data.frame(slot(perf,'x.values'), slot(perf,'y.values'))
names(perf_data) <- c('Specificity','Sensitivity')

plot <- ggplot(perf_data, aes(x = Specificity, y = Sensitivity)) + 
geom_line() +
ggtitle('ROC Curve') +
geom_text(x = 0.4, y = 0.4, label = paste('AUC = ',performance(pred, measure = "auc")@y.values[[1]])) +
coord_cartesian(xlim = c(1,0)) +
theme_classic()

# %%
plot

ggsave('ROC_Plots.png',
       device = 'png', 
       width = 5, 
       height = 5, 
       units = "in", 
       path = '~/Torkamani_Projects/20210712_Analysis-RegeniePaper/CAD_PRS/SCT/PRS_Calculated/')

# %%
data['cutoff'] <- as.factor(data['sum_PRS_std'] > 0.842)

# %%
head(data)
# Out:
#   ID     N     ISP12 AGISP12 sum_PRS  sum_PRS_std cutoff
# 1 100047 12153 0     70      10566.01 -1.87069893 FALSE
# 2 100056 12153 0     81      10571.95 -0.03823715 FALSE
# 3 100104 12153 0     70      10568.44 -1.11961102 FALSE
# 4 100108 12153 0     77      10570.00 -0.63944769 FALSE
# 5 100193 12153 0     74      10574.26  0.67754426 FALSE
# 6 100201 12153 0     77      10570.73 -0.41283255 FALSE

# %%
data$ISP12 <- as.integer(data$ISP12)
res.cox <- coxph(Surv(AGISP12, ISP12) ~ cutoff, data = data)
summary(res.cox)
# Out:
# Call:
# coxph(formula = Surv(AGISP12, ISP12) ~ cutoff, data = data)
#
#   n= 12153, number of events= 2610
#
#               coef exp(coef) se(coef)     z Pr(>|z|)
# cutoffTRUE 0.20614   1.22893  0.04612 4.469 7.85e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#            exp(coef) exp(-coef) lower .95 upper .95
# cutoffTRUE     1.229     0.8137     1.123     1.345
#
# Concordance= 0.52  (se = 0.004 )
# Likelihood ratio test= 19.25  on 1 df,   p=1e-05
# Wald test            = 19.97  on 1 df,   p=8e-06
# Score (logrank) test = 20.05  on 1 df,   p=8e-06

# %%
plot <- ggsurvplot(survfit(Surv(AGISP12, ISP12) ~ cutoff, data = data), data = data, fun = "event")

# %%
plot
ggsave('Cumulative_Risk_Plots.png',
       device = 'png', 
       width = 5, 
       height = 5, 
       units = "in", 
       path = '~/Torkamani_Projects/20210712_Analysis-RegeniePaper/CAD_PRS/SCT/PRS_Calculated/')
