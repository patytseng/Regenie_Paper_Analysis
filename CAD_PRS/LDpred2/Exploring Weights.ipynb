# %%
data <- read.csv('V15')

# %%
head(data)
# Out:
#   chr pos    a0 a1 V15
# 1 1   752721 A  G  -4.677015e-05
# 2 1   754182 A  G  -2.480259e-05
# 3 1   760912 C  T  -4.030814e-05
# 4 1   768448 G  A   3.065984e-06
# 5 1   779322 A  G   1.657315e-05
# 6 1   838555 C  A   1.299784e-05

# %%
library(ggplot2)

# %%
ggplot(data, aes(x = pos, y = V15, color = chr)) + 
geom_line()+
theme_classic()
# Out:
# plot without title
